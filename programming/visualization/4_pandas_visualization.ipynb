# %% [markdown]
# ### Pandas Visualization
# - https://pandas.pydata.org/pandas-docs/stable/visualization.html

# %%
# %matplotlib inline
# %config InlineBackend.figure_formats = {'png', 'retina'}

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ts = pd.Series(np.random.randn(1000), index=pd.date_range('1/1/2000', periods=1000))
ts = ts.cumsum()   # 누적
ts.plot()
plt.show()

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index=ts.index, columns=['A', 'B', 'C', 'D'])
df = df.cumsum()
df.tail()
# Out:
#                    A         B          C          D
# 2002-09-22  2.296663 -6.073580 -11.305445  18.278888
# 2002-09-23  2.348737 -5.405261 -12.060600  19.127642
# 2002-09-24  3.995472 -4.119735 -12.832629  19.477393
# 2002-09-25  4.129183 -5.880460 -11.853505  19.756353
# 2002-09-26  4.234669 -7.199495 -11.818665  21.016610

# %%
df.plot()
plt.legend(loc='best')
plt.show()

# %% [markdown]
# - bar
# - pie
# - scatter

# %% [markdown]
# ##### Seaborn data set
# - https://github.com/mwaskom/seaborn-data

# %%
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris[:10].plot()
plt.legend(loc='best')
plt.show()

# %%
iris[:10].plot(kind="bar")
plt.show()

# %%
iris_pie = iris.species.value_counts()
iris_pie.plot.pie(autopct='%d%%') # decimal %
plt.axis('equal') # 안쓰면 겹쳐 나옴
plt.show()

# %%
iris.plot.scatter(x='sepal_length', y='sepal_width')
plt.show()

# %%
setosa = iris[iris["species"] == "setosa"]
versicolor = iris[iris["species"] == "versicolor"]
virginica = iris[iris["species"] == "virginica"]

# %%
ax = setosa.plot.scatter(x='sepal_length', y='sepal_width', c="red")
versicolor.plot.scatter(x='sepal_length', y='sepal_width', c="blue", ax=ax) # ax : 같은 플롯에 그려줌
virginica.plot.scatter(x='sepal_length', y='sepal_width', c="black", ax=ax)
plt.show()
