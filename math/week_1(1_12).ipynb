# %% [markdown]
# # 데이터 사이언스 학습 안내
# - 기초 수학 이론
#     - 선형대수
#     - 미분과 적분
#     - 최적화
#     - 확률론
# - 컴퓨터 관리 및 프로그래밍 기술
#     - 리눅스 운영체제 사용법
#     - 프로그래밍 언어
#     - 데이터베이스 시스템
#     - 병렬처리, 가상화, 클라우드 사용법
# - 데이터 분석 이론
#     - 확률 모형
#     - 검정 및 추정
#     - 회귀 분석과 분류, 클러스터링
# - 해당 분야에 대한 전문 지식
#     - 해당 분야의 정보를 이해하고 분석 결과가 올바른지를 판단할 수 있는 능력
#     - 이미지 처리, 음성/음향 처리, 텍스트 처리 등의 자료 전처리 기술

# %% [markdown]
# # 데이터 분석의 소개

# %% [markdown]
# ## 데이터 사이언스란?
# 데이터 사이언스란 데이터를 수집하고 분석하여 활용하기 위한 모든 기술의 집합을 말하며,
#
# 컴퓨터 사이언스, 수학, 통계학, 머신 러닝(machine learning), 영상 및 신호 처리 등 다양한 학문 분야가 만나는 영역이다.

# %% [markdown]
# ## 데이터 분석이란?
# 데이터 분석이란 어떤 입력 데이터가 주어졌을 때, 입력 데이터 간의 관계를 파악하거나 파악된 관계를 사용하여 원하는 출력 데이터를 만들어 내는 과정으로 볼 수 있다.
#
# 데이터 분석도 분석 목적에 따라 "예측(prediction)", "클러스터링(clustering)", "모사(approximation)" 등 여러가지 문제가 있다.

# %% [markdown]
# ## 예측
# - 숫자, 문서, 이미지, 음성, 영상 등의 여러 가지 입력 데이터를 주면 데이터 분석의 결과로 다른 데이터를 출력하는 분석 방법이다.
#
#
# - 데이터 분석에서 말하는 예측이라는 용어는 시간상으로 미래의 의미는 포함하지 않는다.

# %% [markdown]
# ### <연습문제 1>
# 예측 문제로 풀 수 있는 데이터 분석의 예를 3가지 생각해 보자.

# %% [markdown]
# 1. 대학교에서 출석점수, 시험점수, 과제점수 등을 주면 해당과목 성적을 추정한다.
#
# 2. 결혼정보회사에서 고객의 객관적인 정보를 통해서 등급을 부여한다.
#
# 3. 거리, 교통상황, 날씨, 교통수단 등을 주면 목적지 도착시간을 추정한다.

# %% [markdown]
# ## 입력 데이터와 출력 데이터
# - 입력 데이터 : 분석의 기반이 되는 데이터를 말한다. 다른 말로 독립변수(independent variable), 특징(feature), 설명변수(explanatory variable) 등의 용어를 쓰기도 한다.
#
#
# - 출력 데이터 : 추정하거나 예측하고자 하는 목적 데이터를 말한다. 다른 말로 종속변수(dependent variable)라고 부른다. 종속변수가 뒤에서 설명할 카테고리값이면 라벨(label) 또는 클래스(class)라고 하기도 한다.

# %% [markdown]
# ### <연습문제 2>
# 연습 문제 1에서 생각한 3가지 예측 문제의 입력과 출력을 보다 정확하게 정의해 보자. 중요한 점은 다음과 같다.
#
# - "~등", "같은 것"이란 용어를 사용하지 않고 정확히 입출력 데이터의 개수를 정해야 한다.
#
#
# - 입력이나 출력 데이터값의 숫자 예를 제시하면 더욱 좋다. 예를 들어, 부동산 가격을 예측하기 위해 면적을 입력 데이터로 사용하기로 했다면,
#
#  "40 제곱미터" 혹은 "80 제곱미터"와 같이 실제로 어떤 숫자를 입력데이터로 사용할지 예를 든다.

# %% [markdown]
# 1. 대학교에서 출석점수, 시험점수, 과제점수 등을 주면 해당과목 성적을 추정한다.
#     - 입력데이터 : 출석점수(10%), 시험점수(70%), 과제점수(20%)
#     - 출력데이터 : 학점
#         * A(90점이상), B(80점이상), C(70점이상), D(60점이상), F(60점미만)
#
# |출석점수(10)|시험점수(70)|과제점수(20)|학점
# -|-|-|-|-
# 학생1|    2|  35| 10| F
# 학생2|	8|	50|	20|	C
# 학생3|	5|	70|	10|	B
# 학생4|	10|	65|	18|	A
# 학생5|	10|	60|	15|	B
# 학생6|	9|	60|	20|	B
# 학생7|	8|	40|	12|	D
# 학생8|	9|	55|	15|	C
# 학생9|	9|	20|	20|	F
# 학생10|	10|	55|	15|	B
#
# 2. 결혼정보회사에서 고객의 객관적인 정보를 통해서 등급을 부여한다.
#     - 입력데이터 : 나이, 직업, 자산, 외모, 학력
#     - 출력데이터 : 등급
#         * 교통상황 : 혼잡할수록 숫자가 큼(1~5)
#         * 날씨 : 날씨가 안 좋을 수록 숫자가 큼(1~5)
#         * 교통수단 : 차(1), 지하철(2), 버스(3), 도보(4)
#
# |  거리|	교통상황|	날씨|	교통수단|	도착시간
# -|-|-|-|-|-
# 경로1|	20km|	2|	3|	1|	20분
# 경로2|	15km|	2|	2|	2|	10분
# 경로3|	6km|	3|	5|	4|	1시간 10분
# 경로4|	10km|	5|	1|	1|	15분
# 경로5|	3km|	4|	1|	4|	30분
# 경로6|	5km|	1|	2|	4|	50분
# 경로7|	12km|	1|	3|	3|	20분
# 경로8|	5km|	1|	3|	4|	55분
# 경로9|	8km|	2|	4|	2|	15분
# 경로10|	25km|	2|	2|	2|	15분
#
#
#
#
# 3. 거리, 교통상황, 날씨, 교통수단 등을 주면 목적지 도착시간을 추정한다.
#     - 입력데이터 : 거리, 교통상황, 날씨, 교통수단
#     - 출력데이터 : 목적지 도착시간
#         * 자산이 많을수록 숫자가 큼(1~5)
#         * 학력이 좋을수록 숫자가 큼(1~5)
#
# |  나이|	직업|	자산|	외모|	학력|	등급
# -|-|-|-|-|-|-
# 회원1|	43|	교수|	3|	C|	5|	C
# 회원2|	25|	회사원|	2|	A|	3|	B
# 회원3|	38|	CEO|	5|	B|	2|	A
# 회원4|	55|	공무원|	1|	B|	2|	C
# 회원5|	33|	기자|	1|	A|	3|	B
# 회원6|	28|	대학생|	1|	B|	1|	B
# 회원7|	48|	회사원|	1|	C|	1|	D
# 회원8|	50|	회사원|	2|	B|	2|	C
# 회원9|	35|	의사|	4|	D|	5|	B
# 회원10|	45|	변호사|	4|	C|	5|	B

# %% [markdown]
# ## 규칙기반 방법과 학습기반 방법
# - 규칙기반 방법 : 어떤 입력이 들어오면 어떤 출력이 나오는지를 결정하는 규칙이나 알고리즘을 사람이 미리 만들어 놓는 방법이다.
#
#
# - 학습기반(데이터기반) 방법 : 규칙을 사람이 만드는 것이 아니라, 대량의 데이터를 컴퓨터에 보여줌으로써 스스로 규칙을 만들게 하는 방법이다.

# %% [markdown]
# ## 전처리와 인코딩
# - 문서나 이미지와 같은 현실의 데이터를 컴퓨터가 처리할 수 있는 숫자 데이터로 바꾸는 과정이다.
#
#
# - 단순히 비정형 데이터를 숫자로 바꾸는 것뿐만 아니라, 전체 입력 정보 중 실제로 출력 데이터의 결정에 영향을 미칠만한 핵심 정보를 선택하거나
#
#   복수의 입력 데이터를 조합하여 새로운 입력 데이터를 만드는 것도 전처리의 중요한 역할이다.

# %% [markdown]
# ## 카테고리값
# - 카테고리값은 숫자 값과 달리 주로 기호로 표시되며 비연속적이다.
#
#
# - 두 개의 데이터가 있을 때 이들의 크기나 가치, 혹은 순서를 비교할 수 없다.
#
#
# - 일반적으로 카테고리값은 가질 수 있는 경우의 수가 제한되어 있다. 이러한 경우의 수를 '클래스(class)'라고 부른다.

# %% [markdown]
# ## 회귀분석과 분류
# 예측 문제 중에서 출력하고자 하는 값이 숫자인 경우를 **회귀분석(regression analysis)**이라고 하며, 전통적인 통계분석에서 많이 사용하는 예측 방법이다.
#
# 반대로 출력하고자 하는 값이 카테고리값인 경우는 **분류(classification)**라고 부른다. 머신러닝 방법은 대부분 분류 문제를 풀기위한 방법이다.
