# %% [markdown]
# # 선형대수와 해석기하의 기초

# %% [markdown]
# ## 벡터의 기하학적 의미
#
# $N$ 차원 벡터(vector)  $a$ 는  $N$ 차원의 공간상에서 두 가지 의미로 간주할 수 있다.
#
# - 벡터  $a$ 의 값으로 표시되는 **점(point)**
# - 원점과 벡터  $a$ 의 값으로 표시되는 점을 연결한 **화살표(arrow)**

# %%
a = np.array([1, 2])

plt.annotate('', xy=a, xytext=(0, 0), arrowprops=dict(facecolor='black'))
plt.plot(0, 0, 'kP', ms=20)
plt.plot(a[0], a[1], 'ro', ms=20)
plt.text(0.35, 1.15, "$a$", fontdict={"size": 18})
plt.text(1.15, 2.25, "$(1,2)$", fontdict={"size": 18})

plt.annotate('', xy=a + [-1, 1], xytext=(-1, 1),
             arrowprops=dict(facecolor='black'))
plt.text(-0.7, 2.1, "$a$", fontdict={"size": 18})

plt.xticks(np.arange(-2, 4))
plt.yticks(np.arange(-1, 4))
plt.xlim(-2.4, 3.4)
plt.ylim(-0.8, 3.4)
plt.show()

# %% [markdown]
# ## 벡터의 길이
# $N$차원 벡터의 길이를 벡터 놈(norm) $||a||$으로 정의한다.
#
# $$
# \| a \| = \sqrt{a^T a } = \sqrt{a_1^2 + \cdots + a_N^2}
# $$

# %%
a = np.array([1, 2])
np.linalg.norm(a)
# Out:
# 2.23606797749979

# %% [markdown]
# ## 스칼라와 벡터의 곱

# %%
a = np.array([1, 2])
b = 2 * a
c = -1 * a

plt.annotate('', xy=b, xytext=(0,0), arrowprops=dict(facecolor='red'))
plt.text(0.8, 3.1, "$2a$", fontdict={"size": 18})
plt.text(2.2, 3.8, "$(2, 4)$", fontdict={"size": 18})

plt.annotate('', xy=a, xytext=(0,0), arrowprops=dict(facecolor='gray'))
plt.text(0.1, 1.3, "$a$", fontdict={"size": 18})
plt.text(1.1, 1.4, "$(1, 2)$", fontdict={"size": 18})

plt.plot(c[0], c[1], 'ro', ms=10)
plt.annotate('', xy=c, xytext=(0,0), arrowprops=dict(facecolor='blue'))
plt.text(-1.3, -0.8, "$-a$", fontdict={"size": 18})
plt.text(-3, -2.5, "$(-1, -2)$", fontdict={"size": 18})

plt.plot(0, 0, 'kP', ms=20)

plt.xticks(np.arange(-5, 6))
plt.yticks(np.arange(-5, 6))
plt.xlim(-4.4, 5.4)
plt.ylim(-3.2, 5.2)
plt.show()

# %% [markdown]
# ## 단위 벡터
# 임의의 벡터  $x$ 에 대해 다음 벡터는 벡터  $x$ 와 같은 방향을 가리키는 단위 벡터가 된다.
#
# $$
# \dfrac{x}{\| x \|}
# $$

# %%
a = np.array([1, 0])
b = np.array([0, 1])
c = np.array([1/np.sqrt(2), 1/np.sqrt(2)])
np.linalg.norm(a), np.linalg.norm(b), np.linalg.norm(c)
# Out:
# (1.0, 1.0, 0.9999999999999999)

# %% [markdown]
# ## 유클리드 유사도
# 두 벡터가 가리키는 점의 거리를 구한 것을 **유클리드 거리(Euclidean distance)**라고 한다.
#
# 유클리드 거리가 작아질 수록 커지는 값을 정의할 수 있는데 이를 **유클리드 유사도(Euclidean similarity)**라고 한다.
#
# 두 벡터의 유클리드 거리는 벡터의 차의 길이로 구할 수 있다.
#
# $
# \begin{eqnarray}
# \| a - b \|^2
# &=& \sum_{i=1} (a_i - b_i)^2 \\
# &=& \sum_{i=1} a_i^2 + \sum_{i=1} b_i^2 - 2 \sum_{i=1} a_i b_i \\
# &=& \| a \|^2 + \| b \|^2  - 2 a^Tb
# \end{eqnarray}
# $

# %% [markdown]
# ## 벡터의 내적과 코사인 유사도
#
# - $a^Tb = \|a\|\|b\| \cos\theta$
#
#
# - 두 벡터  $a$ 와  $b$ 가 이루는 각이 90도이면 서로 **직교(orthogonal)**라고 하며  a⊥b 로 표시한다.
#
#   $cos\;90^∘=0$ 이므로 서로 직교인 두 벡터의 내적은 0이된다.
#
#   $a^T b = b^T a = 0   \;\;\;\; \leftrightarrow \;\;\;\; a \perp b$
#
#
# - 두 벡터의 방향이 비슷할 수록 내적의 값이 커지는 성질을 이용하여
#
#   내적의 값을 두 벡터의 유사도(similarity)로 간주하는 것이 **코사인 유사도(cosine similarity)**이다.
#
#   $\text{코사인 유사도} = \dfrac{x^Ty}{\|x\|\|y\|}$
#
#
# - 코사인 유사도를 이용하면 유클리드 거리와 대비되는 개념인 **코사인 거리(cosine distance)**도 정의할 수 있다.
#
#   $\text{코사인 거리} = 1 - \text{코사인 유사도} = 1 - \dfrac{x^Ty}{\|x\|\|y\|}$

# %% [markdown]
# ## 투영

# %% [markdown]
# $a^{\perp b}$ : 벡터 $b$ 에 대한 리젝션 벡터(rejection vector)
#
# $a^{\Vert b}$ : 벡터 $b$ 에 대한 프로젝션 벡터(projection vector)

# %% [markdown]
# - 프로젝션 벡터의 길이
# $$
# \| a^{\Vert b} \| = \|a\|\cos\theta = \dfrac{\|a\|\|b\|\cos\theta}{\|b\|}  = \dfrac{a^Tb}{\|b\|} = \dfrac{b^Ta}{\|b\|}
# $$

# %% [markdown]
# - 프로젝션 벡터와 리젝션 벡터
#
# $a^{\Vert b} = \dfrac{a^Tb}{\|b\|} \dfrac{b}{\|b\|}= \dfrac{a^Tb}{\|b\|^2}b$
#
# $a^{\perp b} = a - a^{\Vert b}$

# %%
a = np.array([1, 2])
b = np.array([2, 0])
a2 = np.dot(a, b)/np.linalg.norm(b) * np.array([1, 0])
a1 = a - a2

plt.annotate('', xy=b, xytext=(0,0), arrowprops=dict(fc='green'))
plt.annotate('', xy=a2, xytext=(0,0), arrowprops=dict(fc='orange'))
plt.annotate('', xy=a1, xytext=(0,0), arrowprops=dict(fc='orange'))
plt.annotate('', xy=a, xytext=(0,0), arrowprops=dict(fc='red'))

plt.plot(0, 0, 'kP', ms=10)
plt.plot(a[0], a[1], 'ro', ms=10)
plt.plot(b[0], b[1], 'ro', ms=10)

plt.text(0.35, 1.15, "$a$", fontdict={"size": 18})
plt.text(1.55, 0.15, "$b$", fontdict={"size": 18})
plt.text(-0.5, 1.05, "$a^{\perp b}$", fontdict={"size": 18})
plt.text(0.50, 0.15, "$a^{\Vert b}$", fontdict={"size": 18})

plt.xticks(np.arange(-10, 10))
plt.yticks(np.arange(-10, 10))
plt.xlim(-1.2, 4.1)
plt.ylim(-0.5, 3.2)
plt.show()

# %% [markdown]
# ## 직선의 방정식

# %% [markdown]
# $w^T(x - w) = w^Tx - w^Tw = w^Tx - \| w \|^2 = 0$

# %%
w = np.array([1, 2])
x1 = np.array([3, 1])
x2 = np.array([-1, 3])
w0 = 5

plt.annotate('', xy=w, xytext=(0,0), arrowprops=dict(facecolor='black'))
plt.annotate('', xy=x1, xytext=(0,0), arrowprops=dict(facecolor='orange'))
plt.annotate('', xy=x2, xytext=(0,0), arrowprops=dict(facecolor='orange'))

plt.plot(0, 0, 'ro', ms=10)
plt.plot(w[0], w[1], 'ro', ms=10)
plt.plot(x1[0], x1[1], 'ro', ms=10)
plt.plot(x2[0], x2[1], 'ro', ms=10)
plt.plot([-3, 5], [4, 0], 'r-', lw=5)

plt.text(0.3, 1.15, "$w$", fontdict={"size": 18})
plt.text(1.55, 0.25, "$x_1$", fontdict={"size": 18})
plt.text(-0.9, 1.40, "$x_2$", fontdict={"size": 18})
plt.text(1.8, 1.8, "$x_1 - w$", fontdict={"size": 18})
plt.text(-0.2, 2.8, "$x_2 - w$", fontdict={"size": 18})

plt.xticks(np.arange(-2, 5))
plt.yticks(np.arange(-1, 5))
plt.xlim(-2, 5)
plt.ylim(-0.6, 3.6)
plt.show()

# %% [markdown]
# ## 직선과 점의 거리

# %% [markdown]
# $$
# \left| \, \|x'^{\Vert w}\| - \|w\| \right| =
# \left| \dfrac{w^Tx'}{\|w\|} - \|w\| \right| =
# \dfrac{\left|w^Tx' - \|w\|^2 \right|}{\|w\|}
# $$

# %%
w = np.array([1, 2])
x1 = np.array([4, 3])
x2 = np.array([1, 2]) * 2
w0 = 5

plt.annotate('', xy=x1, xytext=(0,0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=x2, xytext=(0,0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=w, xytext=(0,0), arrowprops=dict(facecolor='red'))

plt.plot(0, 0, 'ro', ms=10)
plt.plot(w[0], w[1], 'ro', ms=10)
plt.plot(x1[0], x1[1], 'ro', ms=10)
plt.plot([-3, 7], [4, -1], 'r-', lw=5)
plt.plot([2, 4], [4, 3], 'k:', lw=2)
plt.plot([3, 4], [1, 3], 'k:', lw=2)

plt.text(0, 1.1, "$w$", fontdict={"size": 18})
plt.text(2.5, 2.4, "$x'$", fontdict={"size": 18})
plt.text(0.6, 3.2, "$x'^{\Vert w}$", fontdict={"size": 18})

plt.xticks(np.arange(-3, 15))
plt.yticks(np.arange(-1, 5))
plt.xlim(-3, 7)
plt.ylim(-1, 5)
plt.show()

# %% [markdown]
# ### <연습 문제 1>
# 만약  v 가 원점을 지나는 직선의 방향을 나타내는 단위 벡터라고 하자. 이 때 어떤 점  x 와 그 직선과의 거리의 제곱이 다음과 같음을 증명하라.
#
# $$
# \| x \|^2 - (x^Tv)^2
# $$

# %%
v = np.array([1, 1])
x1 = np.array([4, 1])
x2 = np.array([2, 2]) * 1.5

plt.figure(figsize=(9,9))
plt.annotate('', xy=x1, xytext=(0,0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=x2, xytext=(0,0), arrowprops=dict(facecolor='gray'))
plt.annotate('', xy=v, xytext=(0,0), arrowprops=dict(facecolor='red'))

plt.text(0, 0.8, "$v$", fontdict={"size": 18})
plt.text(4, 1, "$x$", fontdict={"size": 18})
plt.text(2, 2.5, "$x^{\Vert v}$", fontdict={"size": 18})

plt.plot([6, -1], [-1, 6])

plt.xticks(np.arange(-1, 6))
plt.yticks(np.arange(-1, 6))
plt.xlim(-1, 6)
plt.ylim(-1, 6)
plt.show()

# %% [markdown]
# $$\|\text{v}\| = 1 $$
# $$
# \| d \| = Distance\\
# \| x \|^2 = \| d \|^2 + \| x^{\Vert v} \|^2\\
# $$
# 라고 하면, 우리가 찾고자하는 $\| d \|^2 = \| x \|^2 - \| x^{\Vert v} \|^2$
#
# 여기서 투영된 $x^{\Vert v}$의 길이는
# $$
# \| x^{\Vert v} \| = \| x \| \cos{\theta}\\
# \| x^{\Vert v} \| = \dfrac{x^Tv}{\| v \|}\\
# ( \|\text{v}\| = 1 이므로 ) \\
# \| x^{\Vert v} \| = x^Tv
# $$
# 전개 해보면 $\| x^{\Vert v} \| = x^Tv$임을 알수 있다.
# $$
# \\
# $$
#
#
# $$\| d \|^2 = \| x \|^2 - (x^Tv)^2\\ $$

# %% [markdown]
# # 좌표와 변환

# %% [markdown]
# ## 벡터의 선형 종속과 선형 독립
# - 선형 종속(linearly dependent)
# - 선형 독립(linearly independent)

# %% [markdown]
# ### <연습 문제 1>
# 다음 벡터들이 선형 독립인지 선형 종속인지 판별하라.
#
# 1.
# $$
# a = \begin{bmatrix}1 \\ 0\end{bmatrix} ,\;\;
# b = \begin{bmatrix}0 \\ 1\end{bmatrix} \;\;
# $$
# 2.
# $$
# a = \begin{bmatrix}1 \\ 0\end{bmatrix} ,\;\;
# b = \begin{bmatrix}-1 \\ 1\end{bmatrix} \;\;
# $$
# 3.
# $$
# a = \begin{bmatrix}1 \\ 2\end{bmatrix} ,\;\;
# b = \begin{bmatrix}2 \\ 4\end{bmatrix} \;\;
# $$

# %% [markdown]
# 1. 선형 독립
# 2. 선형 독립
# 3. 선형 종속 --> $2a = b$

# %% [markdown]
# ## 랭크
# 행렬의 열 벡터 중 서로 독립인 열 벡터의 최대 갯수를 **열 랭크(column rank)**라고 하고,
#
# 행 벡터 중 서로 독립인 행 벡터의 최대 갯수를 **행 랭크(row rank)**라고 한다.
# - 행 랭크와 열 랭크는 항상 같다.
# - 행렬의 랭크는 열의 갯수와 행의 갯수 중 작은 값보다 커질 수 없다.
# - 랭크가 행의 갯수와 열의 갯수 중 작은 값과 같으면 풀 랭크(full rank)라고 한다.

# %%
A = np.array([[1, 5, 6], [2, 6, 8], [3, 11, 14], [1, 4, 5]])
np.linalg.matrix_rank(A)
# Out:
# 2

# %%
B = np.array([[1, 5, 6], [2, 6, 8], [3, 11, 14], [1, 4, 8]])
np.linalg.matrix_rank(B)  # 풀 랭크
# Out:
# 3

# %% [markdown]
# ## 벡터 공간과 기저 벡터
# 여러개의 벡터를 선형 조합을 하면 다른 벡터를 만들 수 있다.
#
# **벡터 N개가 서로 선형 독립**일 경우, 이 벡터들을 선형 조합하여 만들어지는 모든 벡터의 집합을 **N차원 벡터 공간(vector space)**라고 한다.
#
# 그리고 그 벡터들을 벡터 공간의 **기저 벡터(basis vector)**라고 한다.
#
# 기저 벡터 중에서도 원소 중 하나만 값이 1이고 다른 값은 0으로 이루어진 벡터를 **표준 기저 벡터(standard basis vector)**라고 한다.

# %% [markdown]
# ## 좌표 표현
# **좌표 표현(coordinate representation)** 또는 간단히 **좌표(coordinate)**는 기저 벡터를 선형 조합하여 해당 벡터를 나타내었을 때의 선형 조합 가중치를 말한다.
# - 표준 기저 벡터에 대한 좌표는 원래 벡터와 같다.
# - 기저 벡터가 표준 기저 벡터가 아니면 좌표는 원래의 벡터와 달라진다.

# %% [markdown]
# ## 변환 행렬
# 새로운 기저 벡터들의 기존 기저 벡터에 대한 좌표를 열 벡터로 보고 이를 행렬로 묶은 행렬

# %% [markdown]
# ## 좌표 변환
# 새로운 기저 벡터에 대해 좌표를 계산하는 것을 **좌표 변환(coordinate transform)**이라고 한다.

# %% [markdown]
# ### <연습 문제 3>
# 만약 새로운 기저 벡터가 다음과 같다면 원래의 좌표 (1, 0), (0, 1), (1, 1)은 각각 어떤 좌표값이 될지 계산하라.
#
# $$
# g_1 = \begin{bmatrix} 1 \\ 0 \end{bmatrix} ,\;\;
# g_2 = \begin{bmatrix} -0.5 \\ 1 \end{bmatrix}
# $$

# %%
e1 = np.array([1, 0])
e2 = np.array([0, 1])
a = np.array([1, 1])
g1 = np.array([1, 0])
g2 = np.array([-0.5, 1])

# %%
A = np.vstack([g1, g2]).T
A
# Out:
# array([[ 1. , -0.5],
#        [ 0. ,  1. ]])

# %%
Ainv = np.linalg.inv(A)
Ainv
# Out:
# array([[1. , 0.5],
#        [0. , 1. ]])

# %%
Ainv.dot(e1)
# Out:
# array([1., 0.])

# %%
Ainv.dot(e2)
# Out:
# array([0.5, 1. ])

# %%
Ainv.dot(a)
# Out:
# array([1.5, 1. ])

# %% [markdown]
# ## 이미지 변환

# %% [markdown]
# ### <연습 문제 4>
# 다음 기저 벡터를 이용하여 이미지를 변환하라. 파이썬으로 변환한 이미지를 만들기 전에 어떤 이미지가 나올지 생각해 보자.
#
# $$
# g_1 = \begin{bmatrix} 1 \\ 0 \end{bmatrix} ,\;\;
# g_2 = \begin{bmatrix} -0.5 \\ 1 \end{bmatrix}
# $$

# %%
A
# Out:
# array([[ 1. , -0.5],
#        [ 0. ,  1. ]])

# %%
import matplotlib
import scipy as sp
import scipy.misc

f = sp.misc.face(gray=True)
plt.imshow(f, cmap=mpl.cm.bone)
plt.grid(False)
plt.show()

# %%
import scipy.ndimage

f1 = sp.ndimage.affine_transform(f, A)
plt.imshow(f1, cmap=mpl.cm.bone)
plt.grid(False)
plt.show()
